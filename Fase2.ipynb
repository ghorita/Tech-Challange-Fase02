# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrxelle/FIAP-Tech-Challenge---Modelo-Preditivo-IBOV/blob/main/Tech_Challenge_Ibovespa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importando bibliotecas

# %%
import pandas as pd # Manipulação e análise de dados.
import numpy as np  # Operações matemáticas e vetoriais
import matplotlib.pyplot as plt # Criação de gráficos e visualizações estáticas.
import seaborn as sns # Visualização de dados estatísticos.

# Importações para Testes Estatísticos
from scipy.stats import shapiro # Teste de normalidade.
from scipy.stats import mannwhitneyu # Teste não-paramétrico.

# Importações para Avaliação de Performance do Modelo
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
# accuracy_score: Porcentagem de acertos totais
# classification_report: Métricas detalhadas (Precision, Recall, F1-Score)
# confusion_matrix: Tabela para ver erros de Falso Positivo e Falso Negativo
# roc_curve/auc: Mede a capacidade do modelo de distinguir entre as classes (Sobe/Desce)

# Algoritmos de Machine Learning
from sklearn.naive_bayes import GaussianNB # Modelo baseado em probabilidades.
from sklearn.ensemble import RandomForestClassifier # Conjunto de árvores de decisão.
from sklearn.neighbors import KNeighborsClassifier # Classificação baseada em proximidade/vizinhos (KNN).

# Ferramentas para Visualização de Árvores e Importância de Variáveis
from sklearn.tree import plot_tree # Desenha a estrutura da árvore de decisão
from sklearn import tree # Ferramentas genéricas para árvores
from sklearn.inspection import permutation_importance # Calcula quais colunas (features) são mais importantes para o modelo

# %% [markdown]
# # Primeira análise

# %%
df = pd.read_csv("Dados Históricos - Ibovespa (1).csv")

# %%
df.head(10)
# Out:
#          Data  Último  Abertura  Máxima  Mínima   Vol.    Var%
# 0  05.04.2016  49.054    48.778  49.629  48.149  3,66M   0,56%
# 1  04.04.2016  48.780    50.556  50.556  48.600  3,67M  -3,52%
# 2  01.04.2016  50.562    50.054  50.768  49.361  4,01M   1,01%
# 3  31.03.2016  50.055    51.248  51.248  49.642  4,38M  -2,33%
# 4  30.03.2016  51.249    51.155  52.262  50.900  4,88M   0,18%
# 5  29.03.2016  51.155    50.839  51.765  50.387  4,45M   0,62%
# 6  28.03.2016  50.838    49.687  51.149  49.687  3,62M   2,38%
# 7  24.03.2016  49.657    49.686  49.686  48.778  3,80M  -0,07%
# 8  23.03.2016  49.690    51.005  51.005  49.491  3,75M  -2,59%
# 9  22.03.2016  51.010    51.170  51.215  50.812  4,02M  -0,32%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      5000 non-null   object
#  1   Último    5000 non-null   float64
#  2   Abertura  5000 non-null   float64
#  3   Máxima    5000 non-null   float64
#  4   Mínima    5000 non-null   float64
#  5   Vol.      4999 non-null   object
#  6   Var%      5000 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 273.6+ KB

# %%
df.isnull().sum()
# Out:
# Data        0
# Último      0
# Abertura    0
# Máxima      0
# Mínima      0
# Vol.        1
# Var%        0
# dtype: int64

# %%
df = df[~df['Vol.'].isnull()]

# %% [markdown]
# # Convertendo valores de Volume

# %%
set(df['Vol.'].str[-1])
# Out:
# {'B', 'K', 'M'}

# %%
def converter_volume(vol_str):
    vol_str = str(vol_str).strip().upper()
    if 'M' in vol_str:
        return float(vol_str.replace('M', '').replace(',', '.')) * 1_000_000
    elif 'K' in vol_str:
        return float(vol_str.replace('K', '').replace(',', '.')) * 1_000
    elif 'B' in vol_str:
        return float(vol_str.replace('B', '').replace(',', '.')) * 1_000_000_000
    return float(vol_str)

for col in ['Último', 'Abertura', 'Máxima', 'Mínima']:
    df[col] = df[col].astype(str).str.replace('.', '').str.replace(',', '.').astype(float)

if 'Vol.' in df.columns:
    df['Volume'] = df['Vol.'].apply(converter_volume)
else:
    print("Aviso: Erro. Features não criadas.")
    df['Volume'] = 0

# %% [markdown]
# # Criando coluna DATA

# %%
df['Data'] = pd.to_datetime(df['Data'], dayfirst=True)

df['MesAno'] = pd.to_datetime(df['Data'].dt.strftime('%Y-%m'))

df['Ano'] = df['Data'].dt.year

df.set_index('Data', inplace=True)
df.sort_index(inplace=True)

# %% [markdown]
# # Definindo o Target

# %%
df['Fechamento_Amanhã'] = df['Último'].shift(-1)
df['Previsão'] = (df['Fechamento_Amanhã'] > df['Último']).astype(int)
df.head()
# Out:
#             Último  Abertura  Máxima  Mínima    Vol.    Var%        Volume  \
# Data
# 1996-01-22  4894.0    4909.0  4922.0  4838.0   9,47B  -0,31%  9.470000e+09
# 1996-01-23  4985.0    4897.0  4985.0  4897.0  18,90B   1,86%  1.890000e+10
# 1996-01-24  4945.0    4986.0   502.0   492.0  13,36B  -0,80%  1.336000e+10
# 1996-01-26  4908.0    4945.0  4945.0  4832.0  14,25B  -0,75%  1.425000e+10
# 1996-01-29  4935.0    4908.0  4948.0  4875.0  10,49B   0,55%  1.049000e+10
#
#                MesAno   Ano  Fechamento_Amanhã  Previsão
# Data
# 1996-01-22 1996-01-01  1996             4985.0         1
# 1996-01-23 1996-01-01  1996             4945.0         0
# 1996-01-24 1996-01-01  1996             4908.0         0
# 1996-01-26 1996-01-01  1996             4935.0         1
# 1996-01-29 1996-01-01  1996             5133.0         1

# %%
df['Var%'] = df['Var%'].str.replace('%', '').str.replace(',', '.').astype(float) / 100

# %%
df.describe()
# Out:
#              Último      Abertura        Máxima        Mínima         Var%  \
# count   4999.000000   4999.000000   4999.000000   4999.000000  4999.000000
# mean   31427.021004  31160.185237  31740.543109  30997.231446     0.000678
# min       80.000000     78.000000     54.000000     54.000000    -0.158100
# 25%    10815.000000  10803.000000  10971.000000  10714.000000    -0.010100
# 50%    24829.000000  24376.000000  25001.000000  24328.000000     0.000900
# 75%    53721.000000  53354.500000  54120.000000  52943.500000     0.011800
# max    73517.000000  73508.000000  73794.000000  72534.000000     0.334200
# std    22597.327369  22424.764167  22731.650207  22262.841225     0.020896
#
#              Volume                         MesAno          Ano  \
# count  4.999000e+03                           4999  4999.000000
# mean   1.574635e+09  2006-02-08 20:44:24.532906624  2005.652531
# min    1.121000e+05            1996-01-01 00:00:00  1996.000000
# 25%    3.050000e+06            2001-02-01 00:00:00  2001.000000
# 50%    1.125800e+08            2006-02-01 00:00:00  2006.000000
# 75%    3.262000e+08            2011-03-01 00:00:00  2011.000000
# max    5.406000e+10            2016-04-01 00:00:00  2016.000000
# std    3.883686e+09                            NaN     5.831423
#
#        Fechamento_Amanhã     Previsão
# count        4998.000000  4999.000000
# mean        31432.329732     0.519904
# min            80.000000     0.000000
# 25%         10819.750000     0.000000
# 50%         24836.500000     1.000000
# 75%         53725.000000     1.000000
# max         73517.000000     1.000000
# std         22596.470530     0.499654

# %%
df_agrupado_mes = df.groupby('MesAno')[['Último','Abertura','Máxima','Mínima']].mean()
df_agrupado_mes.head()
# Out:
#                  Último     Abertura       Máxima       Mínima
# MesAno
# 1996-01-01  4993.142857  4959.571429  4374.571429  4279.428571
# 1996-02-01  5271.555556  5282.333333  4529.000000  4442.777778
# 1996-03-01  4286.857143  4287.000000  4349.857143  4023.095238
# 1996-04-01  4568.550000  4558.100000  4592.450000  4746.100000
# 1996-05-01  4811.727273  4786.363636  4825.136364  4753.590909

# %%
df.groupby('Ano').max()
# Out:
#        Último  Abertura   Máxima   Mínima     Vol.    Var%        Volume  \
# Ano
# 1996   7007.0    7007.0   7052.0   7007.0    9,97B  0.0401  5.406000e+10
# 1997  13617.0   13617.0  14005.0  13567.0    9,97B  0.0970  3.398000e+10
# 1998  12299.0   12299.0  12339.0  12121.0    9,91B  0.1868  2.655000e+10
# 1999  17092.0   16778.0  17105.0  16778.0  991,45M  0.3342  9.914500e+08
# 2000  18951.0   18952.0  19047.0  18533.0  988,22M  0.0500  9.882200e+08
# 2001  17889.0   17906.0  18023.0  17704.0  989,42M  0.0761  9.894200e+08
# 2002  14471.0   14455.0  14495.0  14273.0  634,08M  0.0634  6.340800e+08
# 2003  22236.0   22051.0  22046.0  22051.0  989,48M  0.0362  9.894800e+08
# 2004  26196.0   26171.0  26245.0  26108.0  994,96M  0.0530  9.949600e+08
# 2005  33629.0   33625.0  33837.0  33463.0   99,53M  0.0455  3.025300e+08
# 2006  44526.0   44526.0  44675.0  44373.0   99,18M  0.0496  9.553700e+08
# 2007  65791.0   65789.0  66529.0  65278.0   99,30M  0.0495  6.510000e+08
# 2008  73517.0   73508.0  73794.0  72458.0  999,46K  0.1466  1.347000e+07
# 2009  69349.0   69345.0  69785.0  69193.0  990,51K  0.0717  2.840000e+06
# 2010  72996.0   72987.0  73103.0  72534.0  981,63K  0.0411  3.840000e+06
# 2011  71633.0   71631.0  71924.0  70719.0  629,04K  0.0510  5.270000e+06
# 2012  68394.0   68386.0  68259.0  67797.0  692,08K  0.0472  5.970000e+06
# 2013  63312.0   63314.0  63473.0  62415.0    9,67M  0.0365  1.423000e+07
# 2014  61896.0   61836.0  62305.0  61199.0    8,11M  0.0502  8.110000e+06
# 2015  58052.0   57193.0  58575.0  57096.0    7,39M  0.0476  7.390000e+06
# 2016  51249.0   51248.0  52262.0  50812.0    9,31M  0.0660  1.060000e+07
#
#          MesAno  Fechamento_Amanhã  Previsão
# Ano
# 1996 1996-12-01             7007.0         1
# 1997 1997-12-01            13617.0         1
# 1998 1998-12-01            12299.0         1
# 1999 1999-12-01            17092.0         1
# 2000 2000-12-01            18951.0         1
# 2001 2001-12-01            17889.0         1
# 2002 2002-12-01            14471.0         1
# 2003 2003-12-01            22445.0         1
# 2004 2004-12-01            26196.0         1
# 2005 2005-12-01            33629.0         1
# 2006 2006-12-01            45383.0         1
# 2007 2007-12-01            65791.0         1
# 2008 2008-12-01            73517.0         1
# 2009 2009-12-01            70045.0         1
# 2010 2010-12-01            72996.0         1
# 2011 2011-12-01            71633.0         1
# 2012 2012-12-01            68394.0         1
# 2013 2013-12-01            63312.0         1
# 2014 2014-12-01            61896.0         1
# 2015 2015-12-01            58052.0         1
# 2016 2016-04-01            51249.0         1

# %%
df.groupby('Ano').min()
# Out:
#       Último  Abertura  Máxima  Mínima     Vol.    Var%        Volume  \
# Ano
# 1996   489.0     489.0    55.0    54.0   10,03B -0.0464  2.320000e+09
# 1997    87.0      87.0   100.0    98.0   10,02B -0.1497  2.130000e+09
# 1998    80.0      78.0    54.0    84.0   10,01B -0.1581  2.720000e+09
# 1999   117.0      92.0    71.0   108.0  101,79M -0.0997  1.017900e+08
# 2000   145.0     161.0   147.0   149.0  100,65M -0.0637  1.006500e+08
# 2001   117.0     130.0   156.0   148.0  107,29M -0.0918  1.072900e+08
# 2002   126.0      92.0   101.0   141.0  108,39M -0.0653  1.083900e+08
# 2003   116.0     135.0   108.0   116.0  113,34M -0.0387  1.133400e+08
# 2004   194.0     226.0   218.0   223.0  101,26M -0.0615  1.012600e+08
# 2005   259.0     250.0   282.0  2368.0  100,42M -0.0415  2.200000e+07
# 2006   374.0     389.0   385.0   387.0  100,36M -0.0454  3.890000e+06
# 2007   513.0    4237.0   525.0  4194.0    1,71M -0.0663  1.121000e+05
# 2008  3474.0    3148.0   622.0  3362.0    1,01M -0.1139  5.032000e+05
# 2009   421.0     662.0   546.0   387.0    1,01M -0.0524  4.878100e+05
# 2010   682.0     671.0   620.0  6081.0    1,04M -0.0473  6.514800e+05
# 2011   553.0     561.0   576.0   553.0    1,00M -0.0809  5.927500e+05
# 2012   586.0     613.0   619.0   613.0    1,32M -0.0331  6.920800e+05
# 2013   474.0     522.0   500.0   508.0    1,81M -0.0424  1.810000e+06
# 2014   466.0     482.0   474.0   466.0    1,19M -0.0452  7.538400e+05
# 2015   432.0     453.0   569.0   501.0    1,54M -0.0400  1.540000e+06
# 2016   395.0     449.0   391.0   449.0    1,75M -0.0487  1.750000e+06
#
#          MesAno  Fechamento_Amanhã  Previsão
# Ano
# 1996 1996-01-01              489.0         0
# 1997 1997-01-01               87.0         0
# 1998 1998-01-01               80.0         0
# 1999 1999-01-01              117.0         0
# 2000 2000-01-01              145.0         0
# 2001 2001-01-01              117.0         0
# 2002 2002-01-01              126.0         0
# 2003 2003-01-01              116.0         0
# 2004 2004-01-01              194.0         0
# 2005 2005-01-01              259.0         0
# 2006 2006-01-01              374.0         0
# 2007 2007-01-01              513.0         0
# 2008 2008-01-01             3474.0         0
# 2009 2009-01-01              421.0         0
# 2010 2010-01-01              682.0         0
# 2011 2011-01-01              553.0         0
# 2012 2012-01-01              586.0         0
# 2013 2013-01-01              474.0         0
# 2014 2014-01-01              466.0         0
# 2015 2015-01-01              432.0         0
# 2016 2016-01-01              395.0         0

# %%
df.groupby('Ano').mean(numeric_only=True)
# Out:
#             Último      Abertura        Máxima        Mínima      Var%  \
# Ano
# 1996   5528.162393   5546.269231   5540.833333   5375.192308  0.001639
# 1997   9618.514056   9591.020080   9271.614458   9116.795181  0.001914
# 1998   8172.727642   8292.813008   8532.947154   8553.483740 -0.000995
# 1999  10140.508130  10167.597561   9811.060976   9811.902439  0.004207
# 2000  14902.758065  15042.467742  15063.040323  14410.822581 -0.000241
# 2001  13112.569106  13190.670732  13117.890244  12622.922764 -0.000246
# 2002  10067.493976  10379.080321  10471.248996  10520.433735 -0.000539
# 2003  12411.348000  12773.232000  13033.012000  12951.712000  0.002834
# 2004  19486.506024  19766.746988  19895.297189  20604.172691  0.000818
# 2005  24702.080321  25100.305221  25422.895582  24542.285141  0.001107
# 2006  34070.475610  34502.833333  35525.455285  34207.674797  0.001272
# 2007  49399.280488  48949.069106  49093.849593  48160.524390  0.001624
# 2008  50575.819277  51362.329317  51538.602410  50165.574297 -0.001590
# 2009  50081.394309  47848.833333  47915.804878  46449.455285  0.002647
# 2010  62067.129555  59787.020243  61589.834008  60631.631579  0.000126
# 2011  54719.642570  53950.763052  56341.803213  55144.477912 -0.000682
# 2012  54030.821138  54265.609756  55914.109756  54163.422764  0.000382
# 2013  48934.866935  47978.467742  49186.774194  47198.576613 -0.000597
# 2014  48424.479839  48159.020161  48132.798387  47616.411290  0.000007
# 2015  45292.504065  43391.284553  46133.691057  44518.418699 -0.000472
# 2016  38620.241935  39700.870968  40695.854839  39581.967742  0.002323
#
#             Volume  Fechamento_Amanhã  Previsão
# Ano
# 1996  1.145526e+10        5536.974359  0.534188
# 1997  9.703976e+09        9594.787149  0.602410
# 1998  8.921748e+09        8196.686992  0.508130
# 1999  5.392978e+08       10119.170732  0.528455
# 2000  3.484864e+08       14958.129032  0.483871
# 2001  2.369503e+08       13106.256098  0.491870
# 2002  2.697941e+08       10058.381526  0.477912
# 2003  3.181456e+08       12454.716000  0.564000
# 2004  2.928035e+08       19499.666667  0.554217
# 2005  1.160320e+08       24733.345382  0.518072
# 2006  1.245646e+08       34118.752033  0.520325
# 2007  7.157835e+07       49470.142276  0.569106
# 2008  1.842589e+06       50485.172691  0.522088
# 2009  1.525697e+06       50202.536585  0.569106
# 2010  1.879112e+06       62066.793522  0.522267
# 2011  2.376634e+06       54670.915663  0.489960
# 2012  3.064765e+06       53821.170732  0.491870
# 2013  4.840242e+06       49112.633065  0.495968
# 2014  3.560943e+06       48417.104839  0.455645
# 2015  3.550285e+06       45266.605691  0.491870
# 2016  4.521774e+06       38562.524590  0.548387

# %%
def remover_extremos_exato(grupo):
    grupo = grupo.drop(grupo['Máxima'].idxmax())
    grupo = grupo.drop(grupo['Mínima'].idxmin())
    return grupo

df_sem_extremos = df.groupby('Ano', group_keys=False).apply(remover_extremos_exato)

median_sem_extremos = df_sem_extremos.groupby('Ano').median(numeric_only=True)
mean_sem_extremos = df_sem_extremos.groupby('Ano').mean(numeric_only=True)

median_sem_extremos
# Out:
# /tmp/ipython-input-4000773371.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_sem_extremos = df.groupby('Ano', group_keys=False).apply(remover_extremos_exato)
#        Último  Abertura   Máxima   Mínima     Var%        Volume  \
# Ano
# 1996   6109.5    6089.0   6198.0   6041.0  0.00120  1.027000e+10
# 1997   9858.0    9858.0   9838.0   9633.0  0.00530  9.110000e+09
# 1998   9367.0    9426.0   9584.5   9432.5 -0.00010  8.430000e+09
# 1999  11053.0   11074.5  11155.5  11005.0  0.00255  5.523350e+08
# 2000  16321.0   16356.0  16437.5  16025.0 -0.00160  1.947650e+08
# 2001  13900.0   13975.5  14077.0  13734.5 -0.00075  2.164000e+08
# 2002  10583.0   10663.0  10735.0  10569.0 -0.00080  2.557800e+08
# 2003  13110.0   13146.0  13333.0  13120.0  0.00320  2.993900e+08
# 2004  22171.0   22142.0  22348.0  21942.0  0.00140  2.695900e+08
# 2005  26257.0   26385.0  26705.0  26129.0  0.00140  1.118500e+08
# 2006  37300.0   37288.5  37695.0  37003.0  0.00145  1.151300e+08
# 2007  52428.5   52061.5  52733.5  51664.5  0.00295  6.878500e+07
# 2008  58043.0   58597.0  58043.0  56839.0 -0.00110  1.550000e+06
# 2009  51529.5   51358.0  51551.5  50805.5  0.00300  1.490000e+06
# 2010  67306.0   67179.0  67935.0  66993.0  0.00030  1.770000e+06
# 2011  59536.0   58838.0  60104.0  59045.0  0.00060  2.300000e+06
# 2012  58514.5   58544.0  59373.5  58121.5 -0.00060  3.000000e+06
# 2013  53346.0   53064.0  54005.5  52756.5 -0.00080  4.470000e+06
# 2014  52087.0   52087.0  52505.0  51585.5 -0.00125  3.370000e+06
# 2015  48593.5   48143.5  49120.5  47996.0 -0.00135  3.445000e+06
# 2016  41510.5   41510.5  42381.5  41127.0  0.00150  4.045000e+06
#
#       Fechamento_Amanhã  Previsão
# Ano
# 1996             6109.5       1.0
# 1997             9858.0       1.0
# 1998             9367.0       1.0
# 1999            11069.5       1.0
# 2000            16321.0       0.0
# 2001            13882.5       0.0
# 2002            10583.0       0.0
# 2003            13121.5       1.0
# 2004            22178.0       1.0
# 2005            26298.0       1.0
# 2006            37312.5       1.0
# 2007            52481.0       1.0
# 2008            57542.0       1.0
# 2009            51668.0       1.0
# 2010            67306.0       1.0
# 2011            59536.0       0.0
# 2012            58514.5       0.0
# 2013            53346.0       0.0
# 2014            52133.5       0.0
# 2015            48666.0       0.0
# 2016            41478.0       1.0

# %%
df['Fechamento_Amanhã'] = df['Último'].shift(-1)
df['Class'] = (df['Fechamento_Amanhã'] > df['Último']).astype(int)

# %%
correlation_matrix = df[['Último', 'Abertura','Máxima','Mínima','Var%','Volume']].corr(numeric_only=True)

# %% [markdown]
# # FEATURE ENGINING

# %%
df['Variação_Dia'] = df['Último'] - df['Abertura']
df.head()
# Out:
#             Último  Abertura  Máxima  Mínima    Vol.    Var%        Volume  \
# Data
# 1996-01-22  4894.0    4909.0  4922.0  4838.0   9,47B -0.0031  9.470000e+09
# 1996-01-23  4985.0    4897.0  4985.0  4897.0  18,90B  0.0186  1.890000e+10
# 1996-01-24  4945.0    4986.0   502.0   492.0  13,36B -0.0080  1.336000e+10
# 1996-01-26  4908.0    4945.0  4945.0  4832.0  14,25B -0.0075  1.425000e+10
# 1996-01-29  4935.0    4908.0  4948.0  4875.0  10,49B  0.0055  1.049000e+10
#
#                MesAno   Ano  Fechamento_Amanhã  Previsão  Class  Variação_Dia
# Data
# 1996-01-22 1996-01-01  1996             4985.0         1      1         -15.0
# 1996-01-23 1996-01-01  1996             4945.0         0      0          88.0
# 1996-01-24 1996-01-01  1996             4908.0         0      0         -41.0
# 1996-01-26 1996-01-01  1996             4935.0         1      1         -37.0
# 1996-01-29 1996-01-01  1996             5133.0         1      1          27.0

# %%
df['Fechamento_Anterior'] = df['Último'].shift(1)
df.head()
# Out:
#             Último  Abertura  Máxima  Mínima    Vol.    Var%        Volume  \
# Data
# 1996-01-22  4894.0    4909.0  4922.0  4838.0   9,47B -0.0031  9.470000e+09
# 1996-01-23  4985.0    4897.0  4985.0  4897.0  18,90B  0.0186  1.890000e+10
# 1996-01-24  4945.0    4986.0   502.0   492.0  13,36B -0.0080  1.336000e+10
# 1996-01-26  4908.0    4945.0  4945.0  4832.0  14,25B -0.0075  1.425000e+10
# 1996-01-29  4935.0    4908.0  4948.0  4875.0  10,49B  0.0055  1.049000e+10
#
#                MesAno   Ano  Fechamento_Amanhã  Previsão  Class  Variação_Dia  \
# Data
# 1996-01-22 1996-01-01  1996             4985.0         1      1         -15.0
# 1996-01-23 1996-01-01  1996             4945.0         0      0          88.0
# 1996-01-24 1996-01-01  1996             4908.0         0      0         -41.0
# 1996-01-26 1996-01-01  1996             4935.0         1      1         -37.0
# 1996-01-29 1996-01-01  1996             5133.0         1      1          27.0
#
#             Fechamento_Anterior
# Data
# 1996-01-22                  NaN
# 1996-01-23               4894.0
# 1996-01-24               4985.0
# 1996-01-26               4945.0
# 1996-01-29               4908.0

# %%
df['Média_5_Dias'] = df['Último'].rolling(5).mean()
df.head()
# Out:
#             Último  Abertura  Máxima  Mínima    Vol.    Var%        Volume  \
# Data
# 1996-01-22  4894.0    4909.0  4922.0  4838.0   9,47B -0.0031  9.470000e+09
# 1996-01-23  4985.0    4897.0  4985.0  4897.0  18,90B  0.0186  1.890000e+10
# 1996-01-24  4945.0    4986.0   502.0   492.0  13,36B -0.0080  1.336000e+10
# 1996-01-26  4908.0    4945.0  4945.0  4832.0  14,25B -0.0075  1.425000e+10
# 1996-01-29  4935.0    4908.0  4948.0  4875.0  10,49B  0.0055  1.049000e+10
#
#                MesAno   Ano  Fechamento_Amanhã  Previsão  Class  Variação_Dia  \
# Data
# 1996-01-22 1996-01-01  1996             4985.0         1      1         -15.0
# 1996-01-23 1996-01-01  1996             4945.0         0      0          88.0
# 1996-01-24 1996-01-01  1996             4908.0         0      0         -41.0
# 1996-01-26 1996-01-01  1996             4935.0         1      1         -37.0
# 1996-01-29 1996-01-01  1996             5133.0         1      1          27.0
#
#             Fechamento_Anterior  Média_5_Dias
# Data
# 1996-01-22                  NaN           NaN
# 1996-01-23               4894.0           NaN
# 1996-01-24               4985.0           NaN
# 1996-01-26               4945.0           NaN
# 1996-01-29               4908.0        4933.4

# %%
df['Retorno_Pct'] = df['Último'].pct_change().shift(-1)
df['Previsão'] = (df['Retorno_Pct'] > 0.005).astype(int)

# %%
df = df.dropna()
df.head()
# Out:
#             Último  Abertura  Máxima  Mínima    Vol.    Var%        Volume  \
# Data
# 1996-01-29  4935.0    4908.0  4948.0  4875.0  10,49B  0.0055  1.049000e+10
# 1996-01-30  5133.0    4938.0  5148.0  4938.0  22,47B  0.0401  2.247000e+10
# 1996-01-31  5152.0    5134.0  5172.0  5084.0  15,13B  0.0037  1.513000e+10
# 1996-02-01  5269.0    5152.0  5292.0  5098.0  21,30B  0.0227  2.130000e+10
# 1996-02-02  5411.0    5269.0  5411.0  5257.0  26,30B  0.0270  2.630000e+10
#
#                MesAno   Ano  Fechamento_Amanhã  Previsão  Class  Variação_Dia  \
# Data
# 1996-01-29 1996-01-01  1996             5133.0         1      1          27.0
# 1996-01-30 1996-01-01  1996             5152.0         0      1         195.0
# 1996-01-31 1996-01-01  1996             5269.0         1      1          18.0
# 1996-02-01 1996-02-01  1996             5411.0         1      1         117.0
# 1996-02-02 1996-02-01  1996             5333.0         0      0         142.0
#
#             Fechamento_Anterior  Média_5_Dias  Retorno_Pct
# Data
# 1996-01-29               4908.0        4933.4     0.040122
# 1996-01-30               4935.0        4981.2     0.003702
# 1996-01-31               5133.0        5014.6     0.022710
# 1996-02-01               5152.0        5079.4     0.026950
# 1996-02-02               5269.0        5180.0    -0.014415

# %%
df = df[['Último', 'Abertura', 'Variação_Dia', 'Fechamento_Anterior', 'Média_5_Dias', 'Retorno_Pct', 'Fechamento_Amanhã', 'Previsão']]
df.head()
# Out:
#             Último  Abertura  Variação_Dia  Fechamento_Anterior  Média_5_Dias  \
# Data
# 1996-01-29  4935.0    4908.0          27.0               4908.0        4933.4
# 1996-01-30  5133.0    4938.0         195.0               4935.0        4981.2
# 1996-01-31  5152.0    5134.0          18.0               5133.0        5014.6
# 1996-02-01  5269.0    5152.0         117.0               5152.0        5079.4
# 1996-02-02  5411.0    5269.0         142.0               5269.0        5180.0
#
#             Retorno_Pct  Fechamento_Amanhã  Previsão
# Data
# 1996-01-29     0.040122             5133.0         1
# 1996-01-30     0.003702             5152.0         0
# 1996-01-31     0.022710             5269.0         1
# 1996-02-01     0.026950             5411.0         1
# 1996-02-02    -0.014415             5333.0         0

# %% [markdown]
# # MODELOS DE CLASSIFICAÇÃO

# %% [markdown]
# ## RANDOM FOREST CLASSIFIER

# %%
x = df[['Variação_Dia', 'Fechamento_Anterior', 'Média_5_Dias']]
y = df['Previsão']

# %%
x_treino = x[:-30]
y_treino = y[:-30]

# %%
x_teste = x[-30:]
y_teste = y[-30:]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

modelo = RandomForestClassifier(class_weight='balanced', random_state=30)
modelo.fit(x_treino, y_treino)

previsoes = modelo.predict(x_teste)

# %%
acuracia = accuracy_score(y_teste, previsoes)
print(f"Acurácia: {acuracia:.2%}")
# Out:
# Acurácia: 70.00%

# %% [markdown]
# ### VALIDANDO MODELO

# %%
probs_modelo = modelo.predict_proba(x_teste)[:, 1]
accuracy_modelo = accuracy_score(y_teste, previsoes)
reports_modelo = classification_report(y_teste, previsoes)
matriz_modelo = confusion_matrix(y_teste, previsoes)
fpr_modelo, tpr_modelo, _ = roc_curve(y_teste, probs_modelo)
roc_auc = auc(fpr_modelo, tpr_modelo)
importances_modelo = modelo.feature_importances_

# %%
print(reports_modelo)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.88      0.76        16
#            1       0.78      0.50      0.61        14
#
#     accuracy                           0.70        30
#    macro avg       0.72      0.69      0.68        30
# weighted avg       0.72      0.70      0.69        30

# %% [markdown]
# ## NAIVE BAYES

# %%
x_treino = x[:-30]
y_treino = y[:-30]

x_teste = x[-30:]
y_teste = y[-30:]

# %%
gnb = GaussianNB()
gnb.fit(x_treino, y_treino)
# Out:
# GaussianNB()

# %%
y_pred_gnb = gnb.predict(x_teste)

# %%
accuracy_gnb = accuracy_score(y_teste, y_pred_gnb)

print('Acurracy: {:.2f}'.format(round(accuracy_gnb, 2)))
# Out:
# Acurracy: 0.67

# %% [markdown]
# ### VALIDANDO MODELO

# %%
# Métricas de validação
probs_gnb = gnb.predict_proba(x_teste)[:, 1]
accuracy_gnb = accuracy_score(y_teste, y_pred_gnb)
reports_gnb = classification_report(y_teste, y_pred_gnb)
matriz_gnb = confusion_matrix(y_teste, y_pred_gnb)
fpr_gnb, tpr_gnb, _ = roc_curve(y_teste, probs_gnb)
roc_auc_gnb = auc(fpr_gnb, tpr_gnb)
result_gnb = permutation_importance(gnb, x_teste, y_teste, n_repeats=30, random_state=42, n_jobs=-1)
importances_gnb = result_gnb.importances_mean

# %%
print(reports_gnb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.94      0.75        16
#            1       0.83      0.36      0.50        14
#
#     accuracy                           0.67        30
#    macro avg       0.73      0.65      0.62        30
# weighted avg       0.72      0.67      0.63        30

# %% [markdown]
# ## KNEIGHBORS

# %%
x_treino = x[:-30]
y_treino = y[:-30]

x_teste = x[-30:]
y_teste = y[-30:]

# %%
knn = KNeighborsClassifier(n_neighbors=10, metric='euclidean', weights='distance')
knn.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=10, weights='distance')

# %%
y_pred_knn = knn.predict(x_teste)

# %%
accuracy_knn = accuracy_score(y_teste, y_pred_knn)

print('Acurracy: {:.2f}'.format(round(accuracy_knn, 2)))
# Out:
# Acurracy: 0.67

# %% [markdown]
# ### VALIDANDO MODELO

# %%
probs_knn = knn.predict_proba(x_teste)[:, 1]
accuracy_knn = accuracy_score(y_teste, y_pred_knn)
reports_knn = classification_report(y_teste, y_pred_knn)
matriz_knn = confusion_matrix(y_teste, y_pred_knn)
fpr_knn, tpr_knn, _ = roc_curve(y_teste, probs_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)
result_knn = permutation_importance(knn, x_teste, y_teste, n_repeats=30, random_state=42, n_jobs=-1)
importances_knn = result_knn.importances_mean

# %%
print(reports_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.94      0.75        16
#            1       0.83      0.36      0.50        14
#
#     accuracy                           0.67        30
#    macro avg       0.73      0.65      0.62        30
# weighted avg       0.72      0.67      0.63        30

# %% [markdown]
# # ESCOLHENDO MELHOR MODELO

# %%
dict_models = {
    'GNB':accuracy_gnb,
    'KNN':accuracy_knn,
    'RF':acuracia
}

# %%
# Selecionando o modelo com a maior acurácia dentro do dicionário
MelhorModelo = max(dict_models, key=dict_models.get)

# Exibindo os resultados individuais de cada modelo em formato de porcentagem
# O :.2% multiplica o valor por 100 e adiciona o símbolo '%' automaticamente
print('--- Desempenho dos Modelos ---')
print('GNB: {0:.2%}\nKNN: {1:.2%}\nRF: {2:.2%}'.format(accuracy_gnb, accuracy_knn, acuracia))

print('-' * 30)

# Exibindo o vencedor com destaque
print('O Melhor modelo é: {} com o valor: {:.2%} de acuracidade'.format(MelhorModelo, dict_models[MelhorModelo]))
# Out:
# --- Desempenho dos Modelos ---
# GNB: 66.67%
# KNN: 66.67%
# RF: 70.00%
# ------------------------------
# O Melhor modelo é: RF com o valor: 70.00% de acuracidade
